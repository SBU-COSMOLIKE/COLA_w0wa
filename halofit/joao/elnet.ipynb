# %%
# %%file fit.f90
# subroutine fit(n_features, iter, l1_reg,l2_reg, W, Wi, Wj, X, Xi, Xj, R, Ri, Rj, normcolx)
#     integer, intent(in) :: n_features, Wi, Wj, Xi, Xj, Ri, Rj
#     real(8), intent(in) :: l1_reg, l2_reg
#     real(8), dimension(Xi, Xj), intent(in)  :: X
#     real(8), dimension(Xj), intent(in) :: normcolx
#     real(8), dimension(Wi, Wj), intent(inout) :: W
#     real(8), dimension(Ri, Rj), intent(inout) :: R
#     real(8), dimension(Wi) :: wii
#     real(8), dimension(Xi) :: Xii
#     real(8), dimension(Rj) :: tmp
#     real(8) :: normtmp, reg, DNRM2
#     integer :: n_iter, f_iter, iter
#
#     do n_iter = 1, iter
#         do f_iter = 1, Xj
#             do j = 1, Wi
#                 wii(j) = W(j, f_iter)
#             end do
#
#             do j = 1, Xi
#                  Xii(j) = X(j, f_iter)
#             end do
#
#             call DGER(Ri, Rj, 1.0d0, Xii, 1, wii, 1, R, Ri)
#             call DGEMV('T', Ri, Rj, 1.0d0, R, Ri, Xii, 1, 0.0d0, tmp, 1)
#
#             ! print*, tmp
#             normtmp = DNRM2(Rj, tmp, 1)
#             ! print*, normtmp
#
#             if (1.d0  - l1_reg/normtmp >= 0.0d0) then
#                 reg =1.0d0  - l1_reg/normtmp
#             else
#                 reg = 0.0d0
#             end if
#
#             call DCOPY(Rj, tmp, 1, wii, 1)
#             call DSCAL(Rj, reg/(normcolx(f_iter) + l2_reg), wii, 1)
#             call DGER(Ri, Rj, -1.0d0, Xii, 1, wii, 1, R, Ri)
#
#             do j = 1, Wi
#                 W(j, f_iter) = wii(j)
#                 ! print*, W(j, 2)
#             end do
#
#         end do
#     end do
# end subroutine fit
# Out:
# Writing fit.f90

# %%
import sys
import numpy
# !{sys.executable} -m numpy.f2py  -c --link-lapack fit.f90 -m ElNetFortran --fcompiler=gnu95 --f90flags=-O3
# Out:
# /home/grads/miniconda/envs/joao/lib/python3.11/site-packages/numpy/f2py/f2py2e.py:738: VisibleDeprecationWarning:
# distutils has been deprecated since NumPy 1.26.x
# Use the Meson backend instead, or generate wrappers without -c and use a custom build script
#   builder = build_backend(
# running build
# running config_cc
# INFO: unifing config_cc, config, build_clib, build_ext, build commands --compiler options
# running config_fc
# INFO: unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
# running build_src
# INFO: build_src
# INFO: building extension "ElNetFortran" sources
# INFO: f2py options: []
# INFO: f2py:> /tmp/tmp1dg0zwas/src.linux-x86_64-3.11/ElNetFortranmodule.c
# creating /tmp/tmp1dg0zwas/src.linux-x86_64-3.11
# Reading fortran codes...
# 	Reading file 'fit.f90' (format:free)
# Post-processing...
# 	Block: ElNetFortran
# 			Block: fit
# Applying post-processing hooks...
#   character_backward_compatibility_hook
# Post-processing (stage 2)...
# Building modules...
#     Building module "ElNetFortran"...
#     Generating possibly empty wrappers"
#     Maybe empty "ElNetFortran-f2pywrappers.f"
#         Constructing wrapper function "fit"...
#           fit(n_features,iter,l1_reg,l2_reg,w,x,r,normcolx,[wi,wj,xi,xj,ri,rj])
#     Wrote C/API module "ElNetFortran" to file "/tmp/tmp1dg0zwas/src.linux-x86_64-3.11/ElNetFortranmodule.c"
# INFO:   adding '/tmp/tmp1dg0zwas/src.linux-x86_64-3.11/fortranobject.c' to sources.
# INFO:   adding '/tmp/tmp1dg0zwas/src.linux-x86_64-3.11' to include_dirs.
# copying /home/grads/miniconda/envs/joao/lib/python3.11/site-packages/numpy/f2py/src/fortranobject.c -> /tmp/tmp1dg0zwas/src.linux-x86_64-3.11
# copying /home/grads/miniconda/envs/joao/lib/python3.11/site-packages/numpy/f2py/src/fortranobject.h -> /tmp/tmp1dg0zwas/src.linux-x86_64-3.11
# INFO:   adding '/tmp/tmp1dg0zwas/src.linux-x86_64-3.11/ElNetFortran-f2pywrappers.f' to sources.
# INFO: build_src: building npy-pkg config files
# /home/grads/miniconda/envs/joao/lib/python3.11/site-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running build_ext
# INFO: customize UnixCCompiler
# INFO: customize UnixCCompiler using build_ext
# INFO: customize Gnu95FCompiler
# INFO: Found executable /usr/bin/gfortran
# INFO: customize Gnu95FCompiler using build_ext
# INFO: building 'ElNetFortran' extension
# INFO: compiling C sources
# INFO: C compiler: gcc -pthread -B /home/grads/miniconda/envs/joao/compiler_compat -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /home/grads/miniconda/envs/joao/include -fPIC -O2 -isystem /home/grads/miniconda/envs/joao/include -fPIC
#
# creating /tmp/tmp1dg0zwas/tmp
# creating /tmp/tmp1dg0zwas/tmp/tmp1dg0zwas
# creating /tmp/tmp1dg0zwas/tmp/tmp1dg0zwas/src.linux-x86_64-3.11
# INFO: compile options: '-DNPY_DISABLE_OPTIMIZATION=1 -I/tmp/tmp1dg0zwas/src.linux-x86_64-3.11 -I/home/grads/miniconda/envs/joao/lib/python3.11/site-packages/numpy/_core/include -I/home/grads/miniconda/envs/joao/include/python3.11 -c'
# INFO: gcc: /tmp/tmp1dg0zwas/src.linux-x86_64-3.11/ElNetFortranmodule.c
# INFO: gcc: /tmp/tmp1dg0zwas/src.linux-x86_64-3.11/fortranobject.c
# INFO: compiling Fortran sources
# INFO: Fortran f77 compiler: /usr/bin/gfortran -Wall -g -ffixed-form -fno-second-underscore -fPIC -O3 -funroll-loops
# Fortran f90 compiler: /usr/bin/gfortran -O3 -fPIC -O3 -funroll-loops
# Fortran fix compiler: /usr/bin/gfortran -Wall -g -ffixed-form -fno-second-underscore -O3 -fPIC -O3 -funroll-loops
# INFO: compile options: '-I/tmp/tmp1dg0zwas/src.linux-x86_64-3.11 -I/home/grads/miniconda/envs/joao/lib/python3.11/site-packages/numpy/_core/include -I/home/grads/miniconda/envs/joao/include/python3.11 -c'
# INFO: gfortran:f90: fit.f90
# INFO: gfortran:f77: /tmp/tmp1dg0zwas/src.linux-x86_64-3.11/ElNetFortran-f2pywrappers.f
# INFO: /usr/bin/gfortran -Wall -g -Wall -g -shared /tmp/tmp1dg0zwas/tmp/tmp1dg0zwas/src.linux-x86_64-3.11/ElNetFortranmodule.o /tmp/tmp1dg0zwas/tmp/tmp1dg0zwas/src.linux-x86_64-3.11/fortranobject.o /tmp/tmp1dg0zwas/fit.o /tmp/tmp1dg0zwas/tmp/tmp1dg0zwas/src.linux-x86_64-3.11/ElNetFortran-f2pywrappers.o -L/home/grads/miniconda/envs/joao/lib -L/usr/lib/gcc/x86_64-linux-gnu/9 -L/usr/lib/gcc/x86_64-linux-gnu/9 -llapack -llapack -lgfortran -o ./ElNetFortran.cpython-311-x86_64-linux-gnu.so
# Removing build directory /tmp/tmp1dg0zwas
